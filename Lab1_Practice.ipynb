# %%
print("Hello World")
print (2+5)
# Out:
# Hello World
# 7

# %%
a=2
b=3
c="sum"
e=a+b
f=b-a
g=a*b

print(a,b,c)
print(e,f,g)

print(type(a))
print(type(c))
print(type(e))
# Out:
# 2 3 sum
# 5 1 6
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %%
x,y,z="D","A","R"
print(x+y+z)
print(x,y,z)
# Out:
# DAR
# D A R

# %%
#LIST
name=['Dihan','Raj','Ayon']
uni=['AIUB','NSU','IUB']

print(name)
print(name+uni)

#LIST INDEX
print(name[1])

#NEGATIVE LIST INDEX
print(uni[-3])

#LIST SILCING
print(name[0:2])
# Out:
# ['Dihan', 'Raj', 'Ayon']
# ['Dihan', 'Raj', 'Ayon', 'AIUB', 'NSU', 'IUB']
# Raj
# AIUB
# ['Dihan', 'Raj']

# %%
#Correcting Mistake Value At List
Game=['FIFA','PES','COD'] 
Game[2]='eFOOTBALL' 
print(Game)
# Out:
# ['FIFA', 'PES', 'eFOOTBALL']

# %%
#APPENDING & EXTENDING LIST
num=[0,1,2]
num.append(3)
print(num)

num.extend([4,5])
print(num)

#Deleting From List
number=[0,1,3,2]
del number[2]
print(number)
# Out:
# [0, 1, 2, 3]
# [0, 1, 2, 3, 4, 5]
# [0, 1, 2]

# %%
a="2008" 
def myfunc():
  b="AIUB"
  print("One of the best University is " +b)
myfunc()
print("AIUB is created at " +a)
# Out:
# One of the best University is AIUB
# AIUB is created at 2008

# %%
x="Dhaka"
print(x[3])
print(len(x))
for i in x:
  print(i)
# Out:
# k
# 5
# D
# h
# a
# k
# a

# %%
x="dihan"
y="AIUB"
z="       Chittagong,Dhaka"
a="aaaa"
print(x.upper())
print(y.lower())
print(z.strip())
print(a.replace('a','B'))
# Out:
# DIHAN
# aiub
# Chittagong,Dhaka
# BBBB

# %%
vowel=['a','e','i','o','u']
for vh in vowel:
  print(vh)
# Out:
# a
# e
# i
# o
# u

# %%
for i in range(5):
 print(i)
 if i>3:
  break
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  if i<2:
    continue
  print(i)
# Out:
# 2
# 3
# 4
